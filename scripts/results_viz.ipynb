# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.style.use("ggplot")

# %%
results = pd.read_csv("/home/rafael/Projetos/tree_detection/output_adaptive.csv")

# %%
results = results[:-1]

# %%
results
# Out:
#    Unnamed: 0     0  pid
# 0      recall  0.52    1
# 1   precision  0.59    1
# 2          f1  0.56    1
# 3    avg_dist  0.97    1
# 4      recall  0.42    2
# 5   precision  0.50    2
# 6          f1  0.46    2
# 7    avg_dist  0.89    2
# 8      recall  0.51    3
# 9   precision  0.53    3
# 10         f1  0.52    3
# 11   avg_dist  1.26    3
# 12     recall  0.47    4
# 13  precision  0.47    4
# 14         f1  0.47    4
# 15   avg_dist  1.36    4
# 16     recall  0.55    5
# 17  precision  0.47    5
# 18         f1  0.51    5
# 19   avg_dist  1.14    5
# 20     recall  0.48    6
# 21  precision  0.56    6
# 22         f1  0.52    6
# 23   avg_dist  0.93    6
# 24     recall  0.49    7
# 25  precision  0.48    7
# 26         f1  0.49    7
# 27   avg_dist  1.16    7
# 28     recall  0.54    8
# 29  precision  0.54    8
# 30         f1  0.54    8
# 31   avg_dist  0.98    8
# 32     recall  0.57    9
# 33  precision  0.47    9
# 34         f1  0.52    9
# 35   avg_dist  0.87    9
# 36     recall  0.49   10
# 37  precision  0.52   10
# 38         f1  0.51   10
# 39   avg_dist  0.78   10

# %%
results.columns
# Out:
# Index(['Unnamed: 0', '0', 'pid'], dtype='object')

# %%
melted = results.loc[results['Unnamed: 0'] != "avg_dist"]

# %%
#melted = results.melt(id_vars="pid", value_vars=["recall",
#"precision","f1"], var_name = "metric", value_name = "Value")

# %%
melted
# Out:
#    Unnamed: 0     0  pid
# 0      recall  0.49    1
# 1   precision  0.83    1
# 2          f1  0.62    1
# 4      recall  0.39    2
# 5   precision  0.83    2
# 6          f1  0.53    2
# 8      recall  0.47    3
# 9   precision  0.79    3
# 10         f1  0.59    3
# 12     recall  0.42    4
# 13  precision  0.77    4
# 14         f1  0.55    4
# 16     recall  0.58    5
# 17  precision  0.68    5
# 18         f1  0.63    5
# 20     recall  0.55    6
# 21  precision  0.75    6
# 22         f1  0.63    6
# 24     recall  0.53    7
# 25  precision  0.54    7
# 26         f1  0.54    7
# 28     recall  0.56    8
# 29  precision  0.74    8
# 30         f1  0.64    8
# 32     recall  0.51    9
# 33  precision  0.72    9
# 34         f1  0.60    9
# 36     recall  0.51   10
# 37  precision  0.69   10
# 38         f1  0.59   10

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='pid', y='0', hue='Unnamed: 0', data=melted, palette='Set2')
plt.axhline(y = 0.571, color="#66c2a5", linestyle = "dashed", alpha = 0.8)
plt.axhline(y = 0.478, color="#fc8d62", linestyle = "dashed", alpha = 0.8)
plt.axhline(y = 0.501, color="#8da0cb", linestyle = "dashed", alpha = 0.8)
plt.ylabel('Score', fontsize=14)
plt.xlabel('Plot ID', fontsize=14)
plt.ylim(0, 1.0)
plt.savefig("results.png", dpi = 300)
